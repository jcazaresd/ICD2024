# %%
# !pip install keras
# !pip install tensorflow
# !pip install Augmentor
# !pip install tensorflow
# !pip install IPython
# !pip install textattack

# %%
# Importing necessary functions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img

# %%
# Initialising the ImageDataGenerator class.
# We will pass in the augmentation parameters in the constructor.
datagen = ImageDataGenerator(
    rotation_range = 40,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    brightness_range = (0.5, 1.5))

# %%
path = 'C:\\Users\\ingeo\\Almacenamiento interno\\Documentos\\Maestría\\Ciencia de datos\\Ejercicios clase\\images-20240911T202611Z-001\\images\\'
img = load_img(path + 'test_image.jpg')
x = img_to_array(img) # this is a Numpy array with shape (3, 150, 150)
# Reshaping the input image
x = x.reshape((1, ) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# %%
# Generating and saving 5 augmented samples using the above defined parameters.
i = 0
for batch in datagen.flow(x, batch_size = 1, save_to_dir ='C:\\Users\\ingeo\\Almacenamiento interno\\Documentos\\Maestría\\Ciencia de datos\\Ejercicios clase\\images-20240911T202611Z-001\\images\\', save_prefix ='image', save_format ='jpg'):
    i += 1
    if i > 5:
        break

# %%
# Importing necessary functions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img
# Initialising the ImageDataGenerator class.
# We will pass in the augmentation parameters in the constructor.
datagen = ImageDataGenerator(
    rotation_range = 40,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    brightness_range = (0.5, 1.5))
path = 'C:\\Users\\ingeo\\Almacenamiento interno\\Documentos\\Maestría\\Ciencia de datos\\Ejercicios clase\\images-20240911T202611Z-001\\images\\'
img = load_img(path + 'test_image.jpg')
x = img_to_array(img) # this is a Numpy array with shape (3, 150, 150)
# Reshaping the input image
x = x.reshape((1, ) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)
# Generating and saving 5 augmented samples using the above defined parameters.
i = 0
for batch in datagen.flow(x, batch_size = 1, save_to_dir ='C:\\Users\\ingeo\\Almacenamiento interno\\Documentos\\Maestría\\Ciencia de datos\\Ejercicios clase\\images-20240911T202611Z-001\\images\\', save_prefix ='image', save_format ='jpg'):
    i += 1
    if i > 5:
        break

# %%
# Importing necessary library
import Augmentor
# Passing the path of the image directory
p = Augmentor.Pipeline(path)
# Out:
# Initialised with 7 image(s) found.
# Output directory set to C:\Users\ingeo\Almacenamiento interno\Documentos\Maestría\Ciencia de datos\Ejercicios clase\images-20240911T202611Z-001\images\output.

# %%
# Defining augmentation parameters and generating 5 samples
p.flip_left_right(0.5)
p.black_and_white(0.1)
p.rotate(0.3, 10, 10)
p.skew(0.4, 0.5)
p.zoom(probability = 0.2, min_factor = 1.1, max_factor = 1.5)
p.sample(5)
# Out:
# Processing <PIL.Image.Image image mode=1 size=598x598 at 0x1992B460050>: 100%|█████| 5/5 [00:00<00:00, 35.42 Samples/s]

# %%
#importing necessary libraries
import tensorflow as tf
import IPython
import numpy as np

# %%
# !pip install tensorflow-io
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-io (from versions: none)
# ERROR: No matching distribution found for tensorflow-io

# %%
path = 'C:\\Users\\ingeo\\Almacenamiento interno\\Documentos\\Maestría\\Ciencia de datos\\Ejercicios clase\\audios-20240911T202607Z-001\\audios\\'
#to play the audio
IPython.display.Audio(path+"test_audio.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#loading and reading the audio file.
audio_data = tf.audio.AudioIOTensor(path+"test_audio.wav")
print(audio_data)
print(audio_data.shape)
print(audio_data.rate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 #loading and reading the audio file.
# ----> 2 audio_data = tf.audio.AudioIOTensor(path+"test_audio.wav")
#       3 print(audio_data)
#       4 print(audio_data.shape)
#
# AttributeError: module 'tensorflow._api.v2.audio' has no attribute 'AudioIOTensor'

# %%
# !pip uninstall tensorflow-io -y
# Out:
# WARNING: Skipping tensorflow-io as it is not installed.
